# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Heart_Disease_Prediction.csv")

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df["Heart Disease"].value_counts()
# Out:
# Absence     150
# Presence    120
# Name: Heart Disease, dtype: int64

# %%
df["Chest pain type"].value_counts()
# Out:
# 4    129
# 3     79
# 2     42
# 1     20
# Name: Chest pain type, dtype: int64

# %%
df["Chest pain type"].nunique()
# Out:
# 4

# %% [markdown]
# # EDA

# %%
sns.countplot(x=df['Heart Disease'],hue=df['Sex'],data=df)
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %%
sns.countplot(x=df['Heart Disease'],hue=df['Chest pain type'],data=df)
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %%
sns.countplot(x=df['Heart Disease'],hue=df['FBS over 120'],data=df)
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %%
sns.countplot(x=df['Heart Disease'],hue=df['EKG results'],data=df)
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %%
sns.countplot(x=df['Heart Disease'],hue=df['Slope of ST'],data=df)
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='count'>

# %%
df[df['Heart Disease']=="Presence"]
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 2     57    1                2  124          261             0            0
# 6     56    1                3  130          256             1            2
# 7     59    1                4  110          239             0            2
# 8     60    1                4  140          293             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 258   64    1                3  140          335             0            0
# 261   60    1                4  130          206             0            2
# 262   58    1                2  120          284             0            2
# 264   48    1                2  110          229             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.Age[df['Heart Disease']=="Presence"]
# Out:
# 0      70
# 2      57
# 6      56
# 7      59
# 8      60
#        ..
# 258    64
# 261    60
# 262    58
# 264    48
# 269    67
# Name: Age, Length: 120, dtype: int64

# %%
df.Age[df['Heart Disease']=="Presence"].mean()
# Out:
# 56.59166666666667

# %%
df.Age[df['Heart Disease']=="Presence"].min()
# Out:
# 35

# %%
df.Age[df['Heart Disease']=="Presence"].max()
# Out:
# 77

# %%
df.groupby("Heart Disease")["Age"].mean()
# Out:
# Heart Disease
# Absence     52.706667
# Presence    56.591667
# Name: Age, dtype: float64

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.displot(df["Age"])

# %%
sns.barplot(x=df["Heart Disease"],y=df["BP"])
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='BP'>

# %%
sns.barplot(x=df["Heart Disease"],y=df["Max HR"])
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='Max HR'>

# %%
sns.barplot(x=df["Heart Disease"],y=df["ST depression"])
# Out:
# <AxesSubplot:xlabel='Heart Disease', ylabel='ST depression'>

# %% [markdown]
# # CorRelation Matrix:-

# %%
df.corr()
# Out:
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.094401         0.096920  0.273053
# Sex                     -0.094401  1.000000         0.034636 -0.062693
# Chest pain type          0.096920  0.034636         1.000000 -0.043196
# BP                       0.273053 -0.062693        -0.043196  1.000000
# Cholesterol              0.220056 -0.201647         0.090465  0.173019
# FBS over 120             0.123458  0.042140        -0.098537  0.155681
# EKG results              0.128171  0.039253         0.074325  0.116157
# Max HR                  -0.402215 -0.076101        -0.317682 -0.039136
# Exercise angina          0.098297  0.180022         0.353160  0.082793
# ST depression            0.194234  0.097412         0.167244  0.222800
# Slope of ST              0.159774  0.050545         0.136900  0.142472
# Number of vessels fluro  0.356081  0.086830         0.225890  0.085697
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["Heart Disease"] = le.fit_transform(df["Heart Disease"])

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...
